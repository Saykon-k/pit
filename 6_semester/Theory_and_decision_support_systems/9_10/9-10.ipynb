# %%
from sympy.solvers import solve
from sympy import Symbol
from IPython.display import Image
from IPython.display import display

# %% [markdown]
# #                                                    Задание 9

# %%
import os 
l =  Image(filename='task_info.png')  
l1 =  Image(filename='task.png')  
l2 =  Image(filename='res.jpg')  

l

# %%
l1

# %%
l2

# %%
h = Symbol('h')

# %%
solve((h**4) -7*h**3+5*(h**2)+31*h -30)
# Out:
# [-2, 1, 3, 5]

# %%
m1 = Symbol('m1')
m2 = Symbol('m2')
m3 = Symbol('m3')
m4 = Symbol('m4')

# %%
Image(filename='9_rez.jpg')

# %% [markdown]
# m1 + m2 + m3 + m4 == 4

# %% [markdown]
# # Задание 10

# %%
Image(filename='task_10.png')

# %%
Image(filename='iter_1.jpg')

# %%
Image(filename='iter_2.jpg')

# %% [markdown]
# # z-преобразование

# %%
Image(filename='z-1.jpg')

# %%
Image(filename='z-2.jpg')

# %% [markdown]
# # обратный оператор

# %%
Image(filename='obr.jpg')
