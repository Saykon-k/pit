# %%
from sympy.solvers import solve
from sympy import Symbol
from IPython.display import Image
from IPython.display import display

# %% [markdown]
# # 11 задание

# %%
Image(filename='11 task.png')

# %%
Image(filename='11.1 task.png')

# %%
 
l =  Image(filename='1.jpg')  
l1 =  Image(filename='2.jpg')  
l2 =  Image(filename='3.jpg')  
l3 =  Image(filename='4.jpg')  

l

# %% [markdown]
# l1

# %%
l1

# %% [markdown]
# # 12 задание

# %%
Image(filename='12 task.png')

# %%
l2

# %%
l3
