# %%
from pandas import read_csv
from pandas import set_option
from matplotlib import pyplot
import numpy
from pandas.plotting import scatter_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
##данные

# %%
filename = "banknote_authentication.csv"
names = ['дисперсия',
         'асимметрия',
         'эксцесс', 'энтропия','класс']
data = read_csv(filename, names=names)
peek = data.head(20)
peek
# Out:
#     дисперсия  асимметрия  эксцесс  энтропия  класс
# 0     3.62160      8.6661 -2.80730  -0.44699      0
# 1     4.54590      8.1674 -2.45860  -1.46210      0
# 2     3.86600     -2.6383  1.92420   0.10645      0
# 3     3.45660      9.5228 -4.01120  -3.59440      0
# 4     0.32924     -4.4552  4.57180  -0.98880      0
# 5     4.36840      9.6718 -3.96060  -3.16250      0
# 6     3.59120      3.0129  0.72888   0.56421      0
# 7     2.09220     -6.8100  8.46360  -0.60216      0
# 8     3.20320      5.7588 -0.75345  -0.61251      0
# 9     1.53560      9.1772 -2.27180  -0.73535      0
# 10    1.22470      8.7779 -2.21350  -0.80647      0
# 11    3.98990     -2.7066  2.39460   0.86291      0
# 12    1.89930      7.6625  0.15394  -3.11080      0
# 13   -1.57680     10.8430  2.54620  -2.93620      0
# 14    3.40400      8.7261 -2.99150  -0.57242      0
# 15    4.67650     -3.3895  3.48960   1.47710      0
# 16    2.67190      3.0646  0.37158   0.58619      0
# ...

# %%
shape = data.shape;shape
# Out:
# (1372, 5)

# %%
types = data.dtypes;types
# Out:
# дисперсия     float64
# асимметрия    float64
# эксцесс       float64
# энтропия      float64
# класс           int64
# dtype: object

# %%
data = read_csv(filename, names=names)
set_option('display.width', 100)
set_option('precision', 3)
description = data.describe()
print(description)
# Out:
#        дисперсия  асимметрия   эксцесс  энтропия     класс
# count   1372.000    1372.000  1372.000  1372.000  1372.000
# mean       0.434       1.922     1.398    -1.192     0.445
# std        2.843       5.869     4.310     2.101     0.497
# min       -7.042     -13.773    -5.286    -8.548     0.000
# 25%       -1.773      -1.708    -1.575    -2.413     0.000
# 50%        0.496       2.320     0.617    -0.587     0.000
# 75%        2.821       6.815     3.179     0.395     1.000
# max        6.825      12.952    17.927     2.450     1.000

# %%
class_counts = data.groupby('класс').size();class_counts
# Out:
# класс
# 0    762
# 1    610
# dtype: int64

# %%
skew = data.skew();skew
# Out:
# дисперсия    -0.149
# асимметрия   -0.394
# эксцесс       1.089
# энтропия     -1.022
# класс         0.223
# dtype: float64

# %%
#Histograms (гистограммы)

# %%
data.hist()
pyplot.show()

# %%
#ядерные оценки плотности

# %%
data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
pyplot.show()

# %%
#ящики с усами

# %%
data.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False)
pyplot.show()

# %%
correlations = data.corr()
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = numpy.arange(0,len(names),1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(names)
ax.set_yticklabels(names)
pyplot.show()

# %%
correlations = data.corr()
# plot correlation matrix
fig = pyplot.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1)
fig.colorbar(cax)
pyplot.show()

# %%
scatter_matrix(data)
pyplot.show()

# %%
sns.heatmap(data.corr(), annot = True)
plt.show()

# %%
#как можно заметить диспервия и эксцесс имею довольно сильную корреляцию

# %%
#корреляция между классом и другими признакми, как мне кажется, не имеет смысла рассматривать
