# %% [markdown]
# # Сайков К.А
# ##  ПМ - 1801
# ### Методы оптимизации
# ### задание 5

# %%
from IPython.display import Image
from IPython.display import display
z = Image(filename='F:\pit/5_semestr/opt_met/5th_task/info/task.png') 
x = Image(filename='F:\pit/5_semestr/opt_met/2nd_task/info/task.png') 
y = Image(filename='F:/pit/5_semestr/opt_met/4th_task/info/task.png') 
display(z,x, y)

# %%
from IPython.display import Image
Image(filename='info/2nd.jpg')

# %%
from IPython.display import Image
Image(filename='info/4th.jpg')
