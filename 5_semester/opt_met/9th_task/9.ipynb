# %% [markdown]
# # Сайков К.А
# ##  ПМ - 1801
# ### задание 9
# ### Методы оптимизации

# %%
from IPython.display import Image
from IPython.display import display
import os
k = os.path.abspath(os.getcwd())
k = ' '.join([str(elem) for elem in k.split('\\')[:-1]]) 
print(k+"\\8th_task")
a =  Image(filename='info//task.png')  
b = Image(filename='info//task_0.png') 
c = Image(filename='info//info.png') 
display(a,b,c)
# Out:
# F: pit 5_semester opt_met\8th_task

# %%
a =  Image(filename='info//solve_1.jpg')  
b = Image(filename='info//solve_2.jpg') 
c = Image(filename='info//solve_3.jpg') 
display(a,b)

# %%
c
