# %% [markdown]
# # Сайков К.А
# ##  ПМ - 1801
# ### задание 10
# ### Методы оптимизации

# %%
from IPython.display import Image
from IPython.display import display
import os 
k = os.path.abspath(os.getcwd())
k = k.split('\\')[:-1]
k[0] += '\\'
a = k[0]
for i in k[1:]:
    a += i+'\\'
a = a+'info\\task.png'
l =  Image(filename='info//solve_1.jpg')  
l1 =  Image(filename='info//solve_2.jpg')  
z = Image(filename='info//task.png')  
z

# %%
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable

# Create the model
model = LpProblem(name="small-problem", sense=LpMaximize)

# Initialize x1,x2
x1 = LpVariable(name="x1", lowBound=0)
x2 = LpVariable(name="x2", lowBound=0)

#constraints
model += (1.1 * x1 + x2 >= 5, "red_constraint")
model += (x1 + 0.2 * x2 <= 15, "blue_constraint")
model += (x2 <= 3, "yellow_constraint")
model += (0.7 * x1 <= 2, "green_constraint")

# objective function
model += lpSum([x1, (-3) * x2])

# Solve the problem
status = model.solve()
for var in model.variables():
     print(f"{var.name}: {var.value()}")
print(f"objective: {model.objective.value()}")
# Out:
# x1: 2.8571429
# x2: 1.8571429
# objective: -2.7142858000000003

# %%
l

# %%
l1

# %% [markdown]
# ### проверка

# %%
from pulp import LpMaximize, LpProblem, LpStatus, lpSum, LpVariable

# Create the model
model = LpProblem(name="small-problem", sense=LpMaximize)

# Initialize x1,x2
x1 = LpVariable(name="x1", lowBound=0, cat="Integer")
x2 = LpVariable(name="x2", lowBound=0, cat="Integer")

#constraints
model += (1.1 * x1 + x2 >= 5, "red_constraint")
model += (x1 + 0.2 * x2 <= 15, "blue_constraint")
model += (x2 <= 3, "yellow_constraint")
model += (0.7 * x1 <= 2, "green_constraint")

# objective function
model += lpSum([x1, (-3) * x2])

# Solve the problem
status = model.solve()
for var in model.variables():
     print(f"{var.name}: {var.value()}")
print(f"objective: {model.objective.value()}")
# Out:
# x1: 2.0
# x2: 3.0
# objective: -7.0

# %%
# Create the model
model = LpProblem(name="small-problem", sense=LpMaximize)

# Initialize x1,x2
x1 = LpVariable(name="x1", lowBound=0, cat="Integer")
x2 = LpVariable(name="x2", lowBound=0, cat="Integer")

#constraints
model += (1.6 * x1 + 0.2*x2 >= 5, "red_constraint")
model += (0.7*x1 + 0.2 * x2 <= 15, "blue_constraint")
model += (0.2*x2 <= 3, "yellow_constraint")
model += (0.7 * x1 <= 2, "green_constraint")

# objective function
model += lpSum([x1, (-3) * x2])

# Solve the problem
status = model.solve()
for var in model.variables():
     print(f"{var.name}: {var.value()}")
print(f"objective: {model.objective.value()}")
# Out:
# x1: 2.0
# x2: 9.0
# objective: -25.0

# %%
model = LpProblem(name="small-problem", sense=LpMaximize)

# Initialize x1,x2
x1 = LpVariable(name="x1", lowBound=0, )
x2 = LpVariable(name="x2", lowBound=0  )

#constraints
model += ( x1 + x2 >= 5, "red_constraint")
model += (1 +   x2 <= 15, "blue_constraint")
model += (1/10*x2 <= 3, "yellow_constraint")
model += (2.4*x1 <= 2, "green_constraint")

# objective function
model += lpSum([x1, (-3) * x2])

# Solve the problem
status = model.solve()
for var in model.variables():
     print(f"{var.name}: {var.value()}")
print(f"objective: {model.objective.value()}")
# Out:
# x1: 0.83333333
# x2: 4.1666667
# objective: -11.66666677

# %%
model = LpProblem(name="small-problem", sense=LpMaximize)

# Initialize x1,x2
x1 = LpVariable(name="x1", lowBound=0, cat="Integer")
x2 = LpVariable(name="x2", lowBound=0, cat="Integer")

#constraints
model += ( x1 + x2 >= 5, "red_constraint")
model += (1 +   x2 <= 15, "blue_constraint")
model += (1/10*x2 <= 3, "yellow_constraint")
model += (2.4*x1 <= 2, "green_constraint")

# objective function
model += lpSum([x1, (-3) * x2])

# Solve the problem
status = model.solve()
for var in model.variables():
     print(f"{var.name}: {var.value()}")
print(f"objective: {model.objective.value()}")
# Out:
# x1: 0.0
# x2: 5.0
# objective: -15.0
