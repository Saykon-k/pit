# %% [markdown]
# # Сайков К.А
# ##  ПМ - 1801
# ### задание 3а,3б и 3с
# ### Методы оптимизации

# %%
from IPython.display import Image
Image(filename='info/task.png')

# %%
from IPython.display import Image
Image(filename='info/solve3.jpg')

# %%
from IPython.display import Image
Image(filename='info/matr_vid.jpg')

# %%
from IPython.display import Image
Image(filename='info/matr_vid2.jpg')
