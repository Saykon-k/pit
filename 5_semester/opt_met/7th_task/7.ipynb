# %% [markdown]
# # # Сайков К.А
# ##  ПМ - 1801
# ### задание 7
# ### Методы оптимизации

# %%
from IPython.display import Image
from IPython.display import display
z = Image(filename='info//task.png') 
x = Image(filename='F://pit//5_semester//opt_met//2nd_task//info//task.png') 
display(z,x)

# %%
from IPython.display import Image
Image(filename='info/1part.jpg')

# %%
from IPython.display import Image
Image(filename='info/2part.jpg')

# %%
n = Image(filename='info/3part.jpg')
n1 = Image(filename='info/4part.jpg') 
display(n,n1)
