# %% [markdown]
# # Сайков К.А
# ##  ПМ - 1801
# ### задание 8
# ### Методы оптимизации

# %%
from IPython.display import Image
from IPython.display import display
Image(filename='info//task.png')

# %%
Image(filename='info//solve_1_2.jpg')

# %%
Image(filename='info//solve_3.jpg')

# %%
Image(filename='info//solve_4_1.jpg')

# %%
Image(filename='info//solve_4_2.jpg')

# %%
Image(filename='info//solve_4_3.jpg')

# %%
Image(filename='info//solve_4_5.jpg')

# %% [markdown]
# ### 2 часть

# %%
Image(filename='info//task_2.png')

# %%
Image(filename='info//solve_4_part_2_1.jpg')

# %%
Image(filename='info//solve_4_part_2_2.jpg')

# %%
Image(filename='info//solve_4_part_2_3_1.jpg')

# %%
Image(filename='info//solve_4_part_2_3.jpg')

# %%
Image(filename='info//solve_4_part_2_4.jpg')

# %%
Image(filename='info//solve_4_part_2_5.jpg')
