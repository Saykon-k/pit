# %% [markdown]
# # Сайков К.А
# ##  ПМ - 1801
# ### Методы оптимизации
# ### задание 6

# %%
from IPython.display import Image
from IPython.display import display
z = Image(filename='info/task.png') 
n = Image(filename='F://pit//5_semester//opt_met//2nd_task//info//task.png')
x = Image(filename='info/conditions.jpg') 
y = Image(filename='info/solve.jpg') 
display(z,n,x)

# %%
display(y)
