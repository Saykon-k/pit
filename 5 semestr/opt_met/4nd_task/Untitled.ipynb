# %% [markdown]
# # Сайков К.А
# ##  ПМ - 1801
# ### задание 4
# ### Методы оптимизации

# %%
from IPython.display import Image
Image(filename='info/task.png')

# %%
from IPython.display import Image
Image(filename='info/m-meth_1.jpg')

# %%
from IPython.display import Image
Image(filename='info/m-meth_2.jpg')

# %%
import cvxpy as cp
import numpy as np
import math 

x1 = cp.Variable()
x2 = cp.Variable()

#ограничения по условиям задачи
constraints = [x1+x2 >= 5,
               x1+x2 <= 15,
               x2 <= 2,
               x1 <= 3
               ]

#Целевая функция 
obj = cp.Maximize(x1-3*x2)


prob = cp.Problem(obj, constraints)

prob.solve() 

print("status:", prob.status)
print("optimal val:", np.round(prob.value, 5))
print("optimal var:\n{0:12}x1 = {1}\n{0:12}x2 = {2}".format('',np.round(x1.value, 5), np.round(x2.value, 5) ))
# Out:
# status: optimal
# optimal val: -3.0
# optimal var:
#             x1 = 3.0
#             x2 = 2.0

# %%
from IPython.display import Image
Image(filename='info/matr_vid.jpg')
