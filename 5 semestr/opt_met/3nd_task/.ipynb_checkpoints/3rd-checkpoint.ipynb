# %%
from IPython.display import Image
Image(filename='info/solve3.jpg')

# %%
from IPython.display import Image
Image(filename='info/matr_vid.jpg')
